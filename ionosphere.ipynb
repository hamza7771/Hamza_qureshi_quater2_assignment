# %% [markdown]
# <a href="https://colab.research.google.com/github/hamza7771/Hamza_qureshi_quater2_assignment/blob/main/ionosphere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/ionosphere
# Out:
# /content/drive/MyDrive/ionosphere

# %%
df = pd.read_csv('ionosphere_data.csv')
df
# Out:
#      column_a  column_b  column_c  ...  column_ag  column_ah  column_ai
# 0        True     False   0.99539  ...    0.18641   -0.45300          g
# 1        True     False   1.00000  ...   -0.13738   -0.02447          b
# 2        True     False   1.00000  ...    0.56045   -0.38238          g
# 3        True     False   1.00000  ...   -0.32382    1.00000          b
# 4        True     False   1.00000  ...   -0.04608   -0.65697          g
# ..        ...       ...       ...  ...        ...        ...        ...
# 346      True     False   0.83508  ...    0.90546   -0.04307          g
# 347      True     False   0.95113  ...    0.91483    0.04712          g
# 348      True     False   0.94701  ...    0.92697   -0.00577          g
# 349      True     False   0.90608  ...    0.87403   -0.16243          g
# 350      True     False   0.84710  ...    0.85764   -0.06151          g
#
# [351 rows x 35 columns]

# %%
sns.countplot(x='column_ai', data=df)

# %%
df.drop(columns=['column_b'], inplace=True)

# %%
df.rename(columns={'column_ai': 'label'}, inplace=True)
df['label'] = df.label.astype('category')
encoding = {'g': 1, 'b': 0}
df.label.replace(encoding, inplace=True)
df
# Out:
#      column_a  column_c  column_d  ...  column_ag  column_ah  label
# 0        True   0.99539  -0.05889  ...    0.18641   -0.45300      1
# 1        True   1.00000  -0.18829  ...   -0.13738   -0.02447      0
# 2        True   1.00000  -0.03365  ...    0.56045   -0.38238      1
# 3        True   1.00000  -0.45161  ...   -0.32382    1.00000      0
# 4        True   1.00000  -0.02401  ...   -0.04608   -0.65697      1
# ..        ...       ...       ...  ...        ...        ...    ...
# 346      True   0.83508   0.08298  ...    0.90546   -0.04307      1
# 347      True   0.95113   0.00419  ...    0.91483    0.04712      1
# 348      True   0.94701  -0.00034  ...    0.92697   -0.00577      1
# 349      True   0.90608  -0.01657  ...    0.87403   -0.16243      1
# 350      True   0.84710   0.13533  ...    0.85764   -0.06151      1
#
# [351 rows x 34 columns]

# %%
df['column_a'] = df.column_a.astype('float64')

# %%
X = df.values[:, :-1]
y = df.values[:, -1]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=7)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD,Adam
from keras import models
from keras import layers
model = models.Sequential()
model.add(tf.keras.layers.Dense(64, activation= 'relu', input_shape=(1,)))
model.add(tf.keras.layers.Dense(1,activation= 'sigmoid' ))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# ...
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-d80490a850f0> in <module>()
# ----> 1 model.fit(x_train,y_train,epochs=100)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
# ...
